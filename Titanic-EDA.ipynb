# %% [markdown]
# Step 1:Import necessary Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Step 2: Load and Understand the Dataset

# %%
df=pd.read_csv(r"C:\Users\Deepa nayak\OneDrive\Desktop\Elevate Labs-Internship\Day 5\train.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
##Explore the structure:

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# Step 3: Univariate Analysis

# %%
##Explore each column individually:

##Numerical features: Age, Fare, SibSp, Parch

##Categorical features: Sex, Embarked, Pclass, Survived

# %%
## Visuals:

# %%
# Histograms

# %%
df['Age'].hist()
# Out:
# <Axes: >

# %%
df['Fare'].hist()
# Out:
# <Axes: >

# %%
# Countplots

# %%
sns.countplot(x='Survived', data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.countplot(x='Sex', data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x='Pclass', data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
sns.countplot(x='Embarked', data=df)
# Out:
# <Axes: xlabel='Embarked', ylabel='count'>

# %% [markdown]
# Step 4: Handle Missing Values
# Check columns with missing data: Age, Cabin, Embarked

# %%
# Fill missing Age with median
df['Age'].fillna(df['Age'].median(), inplace=True)

# Fill missing Embarked with mode
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# Drop Cabin due to too many missing values
df.drop('Cabin', axis=1, inplace=True)
# Out:
# C:\Users\Deepa nayak\AppData\Local\Temp\ipykernel_9584\2956180287.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)
# C:\Users\Deepa nayak\AppData\Local\Temp\ipykernel_9584\2956180287.py:5: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %% [markdown]
# Step 5: Bivariate Analysis
# Explore relationships between features and the target (Survived):

# %%
# Age vs Survived
sns.boxplot(x='Survived', y='Age', data=df)
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
# Sex vs Survived
sns.barplot(x='Sex', y='Survived', data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='Survived'>

# %%
# Pclass vs Survived
sns.barplot(x='Pclass', y='Survived', data=df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %% [markdown]
# Step 6: Correlation and Multivariate Analysis

# %%
# Encode categorical variables temporarily
df_encoded = df.copy()
df_encoded['Sex'] = df_encoded['Sex'].map({'male': 0, 'female': 1})
df_encoded['Embarked'] = df_encoded['Embarked'].map({'C': 0, 'Q': 1, 'S': 2})

# %%
df_numeric = df_encoded.select_dtypes(include=['int64', 'float64'])

# %%
# Correlation Heatmap
plt.figure(figsize=(10,6))
sns.heatmap(df_numeric.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
##Pairplot

# %%
sns.pairplot(df_encoded[['Survived', 'Age', 'Fare', 'Pclass', 'Sex']])

# %% [markdown]
# Step 7: Insights & Observations

# %% [markdown]
# "Females had higher survival rate than males."
#
# "Younger passengers had a better chance of survival."
#
# "1st class passengers had higher survival rates."

# %% [markdown]
# Summary of Findings
#
# Through Exploratory Data Analysis (EDA) on the Titanic dataset, several key insights emerged:
#
# Gender and Survival:
#
# Females had a significantly higher survival rate compared to males.
#
# This indicates a strong gender-based bias in survival during the disaster.
#
# Passenger Class and Survival:
#
# Passengers from 1st class had the highest survival rates, followed by 2nd and 3rd.
#
# This suggests socio-economic status influenced access to lifeboats.
#
# Age Factor:
#
# Children (especially below 10) had relatively better survival chances.
#
# However, age was not a strong standalone predictor.
#
# Fare and Survival:
#
# Passengers who paid higher fares were more likely to survive, correlating with their class.
#
# Embarked Port:
#
# Most passengers boarded from 'S' (Southampton).
#
# Slightly better survival observed for passengers from 'C' (Cherbourg).
#
# Correlation Insights:
#
# Strong negative correlation between Sex (encoded: male = 0) and Survived.
#
# Pclass also negatively correlated with survival, confirming the class-survival trend.
#
# Missing Data Handling:
#
# Missing values in Age and Embarked were imputed.
#
# Cabin was dropped due to excessive missingness.
